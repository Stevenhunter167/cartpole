# %%
import gym
import tensorflow as tf

# %%
env = gym.make('CartPole-v0')
env.reset()
for _ in range(1000):
    env.render()
    env.step(env.action_space.sample()) # take a random action
env.close()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-5-98c96c1c4244> in <module>
#       2 env.reset()
#       3 for _ in range(1000):
# ----> 4     env.render()
#       5     env.step(env.action_space.sample()) # take a random action
#       6 env.close()
#
# d:\python38\lib\site-packages\gym\core.py in render(self, mode, **kwargs)
#     231
#     232     def render(self, mode='human', **kwargs):
# --> 233         return self.env.render(mode, **kwargs)
#     234
#     235     def close(self):
#
# d:\python38\lib\site-packages\gym\envs\classic_control\cartpole.py in render(self, mode)
#     172
#     173         if self.viewer is None:
# --> 174             from gym.envs.classic_control import rendering
#     175             self.viewer = rendering.Viewer(screen_width, screen_height)
#     176             l, r, t, b = -cartwidth / 2, cartwidth / 2, cartheight / 2, -cartheight / 2
#
# d:\python38\lib\site-packages\gym\envs\classic_control\rendering.py in <module>
#      23
#      24 try:
# ---> 25     from pyglet.gl import *
#      26 except ImportError as e:
#      27     raise ImportError('''
#
# d:\python38\lib\site-packages\pyglet\gl\__init__.py in <module>
#     242     # trickery is for circular import
#     243     _pyglet.gl = _sys.modules[__name__]
# --> 244     import pyglet.window
#
# d:\python38\lib\site-packages\pyglet\window\__init__.py in <module>
#    1878 if not _is_pyglet_doc_run:
#    1879     pyglet.window = sys.modules[__name__]
# -> 1880     gl._create_shadow_window()
#
# d:\python38\lib\site-packages\pyglet\gl\__init__.py in _create_shadow_window()
#     218
#     219     from pyglet.window import Window
# --> 220     _shadow_window = Window(width=1, height=1, visible=False)
#     221     _shadow_window.switch_to()
#     222
#
# d:\python38\lib\site-packages\pyglet\window\win32\__init__.py in __init__(self, *args, **kwargs)
#     128         self._interval = 0
#     129
# --> 130         super(Win32Window, self).__init__(*args, **kwargs)
#     131
#     132     def _recreate(self, changes):
#
# d:\python38\lib\site-packages\pyglet\window\__init__.py in __init__(self, width, height, caption, resizable, style, fullscreen, visible, vsync, display, screen, config, context, mode)
#     578                                     None]:
#     579                 try:
# --> 580                     config = screen.get_best_config(template_config)
#     581                     break
#     582                 except NoSuchConfigException:
#
# d:\python38\lib\site-packages\pyglet\canvas\base.py in get_best_config(self, template)
#     190                     pass
#     191         else:
# --> 192             configs = self.get_matching_configs(template)
#     193         if not configs:
#     194             raise window.NoSuchConfigException()
#
# d:\python38\lib\site-packages\pyglet\canvas\win32.py in get_matching_configs(self, template)
#      67     def get_matching_configs(self, template):
#      68         canvas = Win32Canvas(self.display, 0, _user32.GetDC(0))
# ---> 69         configs = template.match(canvas)
#      70         # XXX deprecate config's being screen-specific
#      71         for config in configs:
#
# d:\python38\lib\site-packages\pyglet\gl\win32.py in match(self, canvas)
#      57             return self._get_arb_pixel_format_matching_configs(canvas)
#      58         else:
# ---> 59             return self._get_pixel_format_descriptor_matching_configs(canvas)
#      60
#      61     def _get_pixel_format_descriptor_matching_configs(self, canvas):
#
# d:\python38\lib\site-packages\pyglet\gl\win32.py in _get_pixel_format_descriptor_matching_configs(self, canvas)
#     100         pfd.cAuxBuffers = self.aux_buffers or 0
#     101
# --> 102         pf = _gdi32.ChoosePixelFormat(canvas.hdc, byref(pfd))
#     103         if pf:
#     104             return [Win32CanvasConfig(canvas, pf, self)]
#
# OSError: exception: access violation writing 0x0000000000000000
